# %% [markdown]
# # Face Detection con MTCNN
#
# [Domingo Mery](http://domingomery.ing.puc.cl)
#
# Departamento de Ciencia de la Computación
#
# Universidad Católica de Chile

# %% [markdown]
# ## Librerías

# %%
# !pip3 install mtcnn
# !pip3 install opencv-contrib-python
# Out:
# Collecting mtcnn
#   Using cached mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
# Collecting joblib>=1.4.2
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting lz4>=4.3.3
#   Downloading lz4-4.3.3-cp310-cp310-macosx_11_0_arm64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.4/212.4 kB 3.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: lz4, joblib, mtcnn
# Successfully installed joblib-1.4.2 lz4-4.3.3 mtcnn-1.0.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (63.7 MB)
# Collecting numpy>=1.17.3
#   Downloading numpy-2.1.2-cp310-cp310-macosx_14_0_arm64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 8.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: numpy, opencv-contrib-python
# Successfully installed numpy-2.1.2 opencv-contrib-python-4.10.0.84
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip

# %% [markdown]
# ## Imagen de prueba

# %%
# !wget https://www.dropbox.com/s/c6eh3vj0ql0wi1r/ingUC.jpg
# Out:
# --2024-10-17 13:05:06--  https://www.dropbox.com/s/c6eh3vj0ql0wi1r/ingUC.jpg
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/sx5a9ty1pieom6bbt5wl7/ingUC.jpg?rlkey=vs3xhgdjjmkj87eplgb5ymmds [following]
# --2024-10-17 13:05:07--  https://www.dropbox.com/scl/fi/sx5a9ty1pieom6bbt5wl7/ingUC.jpg?rlkey=vs3xhgdjjmkj87eplgb5ymmds
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc0948947d56b5b47e13adf39907.dl.dropboxusercontent.com/cd/0/inline/Ccr0FQ7YN4XafOJ5sdVA4I4R7Y4WepeO1MUlNUazeuWTdh1DpLfUvdyeTKfFGMOC84BTqDtsB67QGQvKM2RYRsIoy20xIcnZCHFyoTS_UooJVODrrS_elsQJkZ4bzpeUb14/file# [following]
# --2024-10-17 13:05:08--  https://uc0948947d56b5b47e13adf39907.dl.dropboxusercontent.com/cd/0/inline/Ccr0FQ7YN4XafOJ5sdVA4I4R7Y4WepeO1MUlNUazeuWTdh1DpLfUvdyeTKfFGMOC84BTqDtsB67QGQvKM2RYRsIoy20xIcnZCHFyoTS_UooJVODrrS_elsQJkZ4bzpeUb14/file
# Resolving uc0948947d56b5b47e13adf39907.dl.dropboxusercontent.com (uc0948947d56b5b47e13adf39907.dl.dropboxusercontent.com)... 162.125.5.15
# Connecting to uc0948947d56b5b47e13adf39907.dl.dropboxusercontent.com (uc0948947d56b5b47e13adf39907.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1966216 (1.9M) [image/jpeg]
# Saving to: ‘ingUC.jpg.4’
#
# ingUC.jpg.4         100%[===================>]   1.88M  2.00MB/s    in 0.9s
#
# 2024-10-17 13:05:10 (2.00 MB/s) - ‘ingUC.jpg.4’ saved [1966216/1966216]

# %%
import cv2
import matplotlib.pyplot as plt

# %%
X = cv2.imread('ingUC.jpg')
plt.figure(figsize=(12,30))
plt.imshow(cv2.cvtColor(X, cv2.COLOR_BGR2RGB))
plt.title('ingUC.jpg')
plt.show()

# %% [markdown]
# ## Detección de caras

# %%
from mtcnn.mtcnn import MTCNN
detector = MTCNN()

# %%
face_locations = detector.detect_faces(X)

# %% [markdown]
# ## Despliegue de resultados

# %%
face_locations = detector.detect_faces(X)
plt.figure(figsize=(12,30))
plt.imshow(cv2.cvtColor(X, cv2.COLOR_BGR2RGB))
plt.title('ingUC.jpg')

n = len(face_locations)
for i in range(n):
  bb = face_locations[i]['box']
  x1 = bb[0]
  x2 = bb[0]+bb[2]
  y1 = bb[1]
  y2 = bb[1]+bb[3]
  x = [x1,x1,x2,x2,x1]
  y = [y1,y2,y2,y1,y1]
  plt.plot(x,y,c='red')

plt.show()
