# %% [markdown]
# # VERSION 2024

# %% [markdown]
# <font color='orange'>WARNING-1: No se aceptan soluciones que usen metodologías distintas a la vista en clases.

# %% [markdown]
# # 0) Cambiar el nombre del archivo
#
# <font color='red'>WARNING-2: CAMBIA EL NOMBRE DEL ARCHIVO ipynb INCLUYENDO TU RUT</font>
#
# Ejemplo, si tu RUT es 12.345.678-9, el nombre de este archivo debe cambiarse de "E01_Tu_Rut.ipynb" a "E01_12345678-9.ipynb"

# %% [markdown]
# # 1) Librerías
#
# (1 Punto)
#
# *Todas las librerías de este código deben ir en esta celda. Sólo está permitido usar las librerías del ejemplo visto en clase.*

# %%
 # PREGUNTA 1: ESCRIBA CODIGO AQUI
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # 2) Rectas y líneas
# (2 puntos)
#
#
#
# *   Encuentre la ecuación de la recta que pasa por los puntos (3,5) y (7,8)
# *   Encuentre la intersección de la recta $y=4x+6$ con la recta $y=-2x$
#
# <font color='orange'>VER WARNING-1 MAS ARRIBA</font>

# %%
 # PREGUNTA 2: ESCRIBA CODIGO AQUI
m1=[3,5 ,1] #(x1, y1) = (3,5)
m2=[7,8 ,1] #(x2, y2) = (7,8)

xs=[m1[0],m2[0]]
ys=[m1[1],m2[1]]

plt.plot(xs[0], ys[0], marker="o", markerfacecolor="red", markersize=10)
plt.plot(xs[1], ys[1], marker="o", markerfacecolor="red", markersize=10)

plt.plot(xs,ys, color="blue")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Line for $m_1$ to $m_2$")
plt.show()

ell=np.cross(m1,m2)
print("La ecuación de la recta que pasa por los puntos (3,5) y (7,8) es=", ell)
#Interseccion de la recta

#Line 1
ell1=[4,-1,6]
a1=ell1[0]
b1=ell1[1]
c1=ell1[2]

x1= np.array([])

#Line 2
ell2=[2,1,0]
a2=ell2[0]
b2=ell2[1]
c2=ell2[2]

#Intersection
ell3=np.cross(ell1,ell2)

xi = ell3[0]/ell3[2]
yi = ell3[1]/ell3[2]

print("La intersección de la recta  y=4x+6  con la recta  y=−2x es=", ell3)
# Out:
# La ecuación de la recta que pasa por los puntos (3,5) y (7,8) es= [ -3   4 -11]
# La intersección de la recta  y=4x+6  con la recta  y=−2x es= [-6 12  6]

# %% [markdown]
# # 3) Cargue la Imagen de John Lennon y Despliéguela
#
# (1 Punto)
#
# *Lea erchivo de la imagen se encuentra en este link:*
#
# `https://www.dropbox.com/s/g4hee0epvla4n5j/JohnLennon.jpg`

# %%
 # PREGUNTA 3: ESCRIBA CODIGO AQUI
# !wget https://www.dropbox.com/s/g4hee0epvla4n5j/JohnLennon.jpg
I = cv2.imread("JohnLennon.jpg")
plt.imshow(I)
plt.title("Jhon Lennon")
plt.show()
# Out:
# --2024-08-22 00:04:52--  https://www.dropbox.com/s/g4hee0epvla4n5j/JohnLennon.jpg
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/ds9vmznxcmhjjzqc0exgg/JohnLennon.jpg?rlkey=7qt6nqtyx66berbp5uut9jw0s [following]
# --2024-08-22 00:04:53--  https://www.dropbox.com/scl/fi/ds9vmznxcmhjjzqc0exgg/JohnLennon.jpg?rlkey=7qt6nqtyx66berbp5uut9jw0s
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce1ea673d1e028a0273bede4e07.dl.dropboxusercontent.com/cd/0/inline/CZGk2B6RgVYF0Ww4LOCZMK-VExZlAGuYQSGoN6GcYsr9ziMO3mTAdyVyZZ-4qwru-eCrzuKU1HD4jxFEgKkmzRg7WYUafbfY2HKd55p1ztXLH7n8Msrb5YlcZR7klTOVe-o/file# [following]
# ...

# %% [markdown]
# # 4) Cargue las coordenadas (x,y) de los 68 Landmarks
#
# (1 Punto)
#
# *Los archivos de la coordenadas son:*
#
# `https://www.dropbox.com/s/6xfjsz0ymbctbhr/JL_landmarks_x.npy`
#
# `https://www.dropbox.com/s/18chd3jdw95vmt7/JL_landmarks_y.npy`
#
# *Cargue en `x` el primero archivo, y en `y` el segundo archivo*
#
# Help: [Cómo cargar archivos npy ?](https://www.google.com/search?q=como+cargar+archivos+npy)

# %%
# PREGUNTA 4: ESCRIBA CODIGO AQUI
# !wget https://www.dropbox.com/s/6xfjsz0ymbctbhr/JL_landmarks_x.npy
# !wget https://www.dropbox.com/s/18chd3jdw95vmt7/JL_landmarks_y.npy

x = np.load("JL_landmarks_x.npy")[0]
y = np.load("JL_landmarks_y.npy")[0]
# Out:
# --2024-08-22 00:04:58--  https://www.dropbox.com/s/6xfjsz0ymbctbhr/JL_landmarks_x.npy
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/w3g26mnld0cc7xpg6s58n/JL_landmarks_x.npy?rlkey=ckjb9o7t70n2io2iv8xshhv63 [following]
# --2024-08-22 00:04:58--  https://www.dropbox.com/scl/fi/w3g26mnld0cc7xpg6s58n/JL_landmarks_x.npy?rlkey=ckjb9o7t70n2io2iv8xshhv63
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucb00fab070c6aa20391d4ec2d79.dl.dropboxusercontent.com/cd/0/inline/CZGyCf2OtB8Ub2D0wuYQYT1TplqE4NwnU5YkOLkXgpTJdtlazAARfGxIH4rIxD2E0-6px7_x4ZDyPVu-oKZXEQQ7_In-JO0bkxEl0Cn-CnOcnw_XT0lM5c5UyT6-Fk7q_vM/file# [following]
# ...

# %% [markdown]
# # 5) Despliegue los 68 landmarks en la cara de John Lennon
# (2 Puntos)
#
# *Debe mostrar los 68 puntos sobre la imagen de John Lennon*

# %%
 # PREGUNTA 5: ESCRIBA CODIGO AQUI
plt.imshow(I)
plt.scatter(x,y,s=2, color="white", marker="o")
plt.show()

# %% [markdown]
# # Usando el esquema de la siguiente figura encuentre hacia dónde mira John Lennon en la imagen cargada

# %% [markdown]
# ![Screen Shot 2021-08-22 at 7.40.19 am.png](data:image/png;base64,...)

# %% [markdown]
# # 6) Encuentre el cuadrilatero definido por los ojos y comisura de los labios
#
# (2 Puntos)
#
# *Siguiendo el esquema de la figura muestre el cuadrilatero de los cuatro puntos rojos, debe mostrar los cuatro puntos (esto es el centro de cada ojo, y las comisuras de los labios) y la línea del cuadrilátero, sobre la imagen de John Lennon*
#
# [Cómo están definidos los 68 landmarks?](https://github.com/domingomery/vision/blob/master/clases/Cap02_Geometria/practice/facial_landmarks_68markup.jpg)

# %%
 # PREGUNTA 6: ESCRIBA CODIGO AQUI
ojo_izquierdo_x = np.array([x[36], x[37], x[38], x[39], x[40], x[41]])
ojo_izquierdo_y = np.array([y[36], y[37], y[38], y[39], y[40], y[41]])
ojo_izquierdo_centro_x=np.mean(ojo_izquierdo_x)
ojo_izquierdo_centro_y=np.mean(ojo_izquierdo_y)


ojo_derecho_x = np.array([x[42], x[43], x[44], x[45], x[46], x[47]])
ojo_derecho_y = np.array([y[42], y[43], y[44], y[45], y[46], y[47]])
ojo_derecho_centro_x=np.mean(ojo_derecho_x)
ojo_derecho_centro_y=np.mean(ojo_derecho_y)

#linea ojo izq a der
xs_ojo_izq = [ojo_izquierdo_centro_x,ojo_derecho_centro_x]
ys_ojo_der = [ojo_izquierdo_centro_y, ojo_derecho_centro_y]

#linea ojo der a lab der
xs_ojo_der_lab_der = [ojo_derecho_centro_x, x[54]]
ys_ojo_der_lab_der = [ojo_derecho_centro_y,y[54]]

#linea ojo izq a lab izq
xs_ojo_izq_lab_izq = [ojo_izquierdo_centro_x, x[48]]
ys_ojo_izq_lab_izq = [ojo_izquierdo_centro_y,y[48]]

#linea lab izq a lab der
xs_lab_izq_lab_der = [x[48], x[54]]
ys_lab_izq_lab_der = [y[48],y[54]]

plt.imshow(I)


plt.plot(xs_ojo_izq, ys_ojo_der, color="green")
plt.plot(xs_ojo_der_lab_der, ys_ojo_der_lab_der, color="green")
plt.plot(xs_ojo_izq_lab_izq, ys_ojo_izq_lab_izq, color="green")
plt.plot(xs_lab_izq_lab_der, ys_lab_izq_lab_der, color="green")
plt.scatter(ojo_izquierdo_centro_x,ojo_izquierdo_centro_y,s=5, color="red", marker="o")
plt.scatter(ojo_derecho_centro_x,ojo_derecho_centro_y,s=5, color="red", marker="o")
plt.scatter(x[48], y[48], s=5, color="red", marker="o")
plt.scatter(x[54], y[54], s=5, color="red", marker="o")
plt.show()

# %% [markdown]
# # 7) Defina las coordenadas homogéneas de los cuatro puntos del cuadrilatero
#
# (1 Punto)
#
# Defina los siguientes 4 puntos en ccordenadas homogéneas e imprimalos con `print`.
#
# * Punto m1 : centro del ojo izquierdo
#
# * Punto m2 : centro ded ojo derecho
#
# * Punto m3 : comisura izquierda del labio
#
# * Punto m4 : comisura derecha del labio

# %%
 # PREGUNTA 7: ESCRIBA CODIGO AQUI
m1=[ojo_izquierdo_centro_x,ojo_izquierdo_centro_y,1]
m2=[ojo_derecho_centro_x,ojo_derecho_centro_y,1]
m3=[x[48],y[48],1]
m4=[x[54],y[54],1]

print(m1)
print(m2)
print(m3)
print(m4)
# Out:
# [330.25, 294.5, 1]
# [393.5, 298.0, 1]
# [330.5, 374.0, 1]
# [389.0, 374.0, 1]

# %% [markdown]
# # 8) Encuentre mc, el centro del cuadrilátero y despliéguelo
#
# (2 Puntos)
#
# *Usando la metodología vista en clases -con coordenadas homogénas-, y la figura de explicación, encuentre el centro del cuadrilatero como la intersección de las rectas L1 (definida como la línea que va desde el centro entre m1 y m2 al centro entre m3 y m4) y L2 (definida como la línea que va desde el centro entre m1 y m3 al centro entre m2 y m4).*
#
# *Debe mostrar los cuatro puntos del cuadrilátero, la cruz central, y el centro del cuadrilátero sobre la imagen de John Lennon.*

# %%
 # PREGUNTA 8: ESCRIBA CODIGO AQUI
plt.imshow(I)
punto_medio_m1_m2=np.array([(m1[0]+m2[0])/2,(m1[1]+m2[1])/2])
plt.scatter(punto_medio_m1_m2[0],punto_medio_m1_m2[1],s=5, color="red", marker="o")
punto_medio_m3_m4=np.array([(m3[0]+m4[0])/2,(m3[1]+m4[1])/2])
plt.scatter(punto_medio_m3_m4[0],punto_medio_m3_m4[1],s=5, color="green", marker="o")
m5=[punto_medio_m1_m2[0],punto_medio_m1_m2[1],1]
m6=[punto_medio_m3_m4[0],punto_medio_m3_m4[1],1]
xs3=[m5[0],m6[0]]
ys3=[m5[1],m6[1]]
plt.plot(xs3,ys3,color="blue")
punto_medio_m1_m3=np.array([(m1[0]+m3[0])/2,(m1[1]+m3[1])/2])
plt.scatter(punto_medio_m1_m3[0],punto_medio_m1_m3[1],s=5, color="blue", marker="o")
punto_medio_m2_m4=np.array([(m2[0]+m4[0])/2,(m2[1]+m4[1])/2])
plt.scatter(punto_medio_m2_m4[0],punto_medio_m2_m4[1],s=5, color="yellow", marker="o")
m7=[punto_medio_m1_m3[0],punto_medio_m1_m3[1],1]
m8=[punto_medio_m2_m4[0],punto_medio_m2_m4[1],1]
xs4=[m7[0],m8[0]]
ys4=[m7[1],m8[1]]
plt.plot(xs4,ys4,color="blue")
L1 = np.cross(m5, m6)
L2 = np.cross(m7, m8)
interseccion = np.cross(L1, L2)

if interseccion[2] != 0:
    mc = interseccion / interseccion[2]
else:
    mc = interseccion

plt.imshow(I)
plt.scatter(mc[0], mc[1], s=50, color="magenta", marker="x")

plt.show()

# %% [markdown]
# # 9) Hacia dónde mira John Lennon? (Parte 1)
#
# (2 Puntos)
#
# *Encuentre la ecuación de la recta que pasa por mc y la punta de la nariz y grafique esa línea desde mc hasta mq, donde mq es el punto de la línea en x=500.*
#
# *Debe mostrar los cuatro puntos del cuadrilátero, la línea del cuadrilátero, el centro del cuadrilátero, y la línea encontrada, sobre la imagen de John Lennon.*

# %%
 # PREGUNTA 9: ESCRIBA CODIGO AQUI
m_nariz_x=x[33]
m_nariz_y=y[33]
m_nariz=[m_nariz_x,m_nariz_y,1]
L_mc_nariz=np.cross(mc, m_nariz)

x_mq=500
y_mq=-(L_mc_nariz[0]*x_mq+L_mc_nariz[2])/L_mc_nariz[1]
mq=[x_mq,y_mq,1]

plt.imshow(I)
plt.scatter([m1[0], m2[0], m3[0], m4[0]], [m1[1], m2[1], m3[1], m4[1]], s=3, color='blue', marker='o', label='Puntos del cuadrilátero')
plt.scatter(m_nariz[0], m_nariz[1], s=8, color="green", marker="o", label='Punta de la nariz')
plt.plot([punto_medio_m1_m2[0], punto_medio_m3_m4[0]], [punto_medio_m1_m2[1], punto_medio_m3_m4[1]], color="blue", label='L1')
plt.plot([punto_medio_m1_m3[0], punto_medio_m2_m4[0]], [punto_medio_m1_m3[1], punto_medio_m2_m4[1]], color="purple", label='L2')
plt.scatter(mc[0], mc[1], s=30, color="yellow", marker="x", label='Centro del cuadrilátero mc')
plt.plot([mc[0], mq[0]], [mc[1], mq[1]], color='red', label='A donde mira John Lennon')
plt.legend()

plt.show()

# %% [markdown]
# # 10) Hacia dónde mira John Lennon? (Parte 2)
#
# (2 Puntos)
#
# *Desplace la línea encontrada en el paso anterior de tal forma que comience (no desde mc) sino desde mt, definido como el punto medio entre m1 y m2.*
#
# *Debe mostrar la nueva línea encontrada sobre la imagen de John Lennon.*

# %%
 # PREGUNTA 10: ESCRIBA CODIGO AQUI
mt=np.array([(m1[0]+m2[0])/2,(m1[1]+m2[1])/2])
L_mt_nariz = np.cross(mt, m_nariz)
x_mq = 500
y_mq = -(L_mt_nariz[0] * x_mq + L_mt_nariz[2]) / L_mt_nariz[1]
mq = np.array([x_mq, y_mq, 1])
plt.imshow(I)
plt.scatter([m1[0], m2[0], m3[0], m4[0]], [m1[1], m2[1], m3[1], m4[1]], s=3, color='blue', marker='o', label='Puntos del cuadrilátero')
plt.scatter(m_nariz[0], m_nariz[1], s=8, color="green", marker="o", label='Punta de la nariz')
plt.plot([punto_medio_m1_m2[0], punto_medio_m3_m4[0]], [punto_medio_m1_m2[1], punto_medio_m3_m4[1]], color="blue", label='L1')
plt.plot([punto_medio_m1_m3[0], punto_medio_m2_m4[0]], [punto_medio_m1_m3[1], punto_medio_m2_m4[1]], color="purple", label='L2')
plt.scatter(mc[0], mc[1], s=30, color="yellow", marker="x", label='Centro del cuadrilátero mc')
plt.plot([mt[0], mq[0]], [mt[1], mq[1]], color='red', label='A donde mira John Lennon')
plt.legend()
plt.show()

# %% [markdown]
# # <font color='red'>SUBIR EJERCICIO DE FORMA INDIVIDUAL A CANVAS
#
# EL NOMBRE DEL ARCHIVO DEBE SER SEGÚN EL PUNTO 0) VER ARRIBA</font>
